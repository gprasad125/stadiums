# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/restaurants.csv')
df.dropna(inplace=True)
df.reset_index(inplace=True)

df.head()
# Out:
#    index                                 name  rating  price  \
# 0      0                               Oriole     5.0    4.0
# 1      1  Spinning J Bakery and Soda Fountain     4.5    2.0
# 2      2                               S.K.Y.     4.5    3.0
# 3      3                              Kai Zan     4.5    3.0
# 4      4               Sabroso! Mexican Grill     4.5    2.0
#
#                                   categories   latitude  longitude league  \
# 0                              [newamerican]  41.886097 -87.644948    NBA
# 1   [coffee,  breakfast_brunch,  sandwiches]  41.899450 -87.697160    NBA
# 2   [newamerican,  cocktailbars,  wine_bars]  41.857808 -87.658043    NBA
# 3           [asianfusion,  japanese,  sushi]  41.895505 -87.691541    NBA
# 4  [mexican,  breakfast_brunch,  newmexican]  41.893190 -87.667530    NBA
#
#             team        stadium  team_latitude  team_longitude     state  \
# 0  Chicago Bulls  United Center      41.880556      -87.674167  Illinois
# 1  Chicago Bulls  United Center      41.880556      -87.674167  Illinois
# 2  Chicago Bulls  United Center      41.880556      -87.674167  Illinois
# 3  Chicago Bulls  United Center      41.880556      -87.674167  Illinois
# 4  Chicago Bulls  United Center      41.880556      -87.674167  Illinois
#
#       city
# 0  Chicago
# 1  Chicago
# 2  Chicago
# 3  Chicago
# 4  Chicago

# %%
df.head()
# Out:
#    index                                 name  rating  price   categories  \
# 0      0                               Oriole     5.0    4.0  newamerican
# 1      1  Spinning J Bakery and Soda Fountain     4.5    2.0   sandwiches
# 2      2                               S.K.Y.     4.5    3.0    wine_bars
# 3      3                              Kai Zan     4.5    3.0        sushi
# 4      4               Sabroso! Mexican Grill     4.5    2.0   newmexican
#
#     latitude  longitude league           team        stadium  team_latitude  \
# 0  41.886097 -87.644948    NBA  Chicago Bulls  United Center      41.880556
# 1  41.899450 -87.697160    NBA  Chicago Bulls  United Center      41.880556
# 2  41.857808 -87.658043    NBA  Chicago Bulls  United Center      41.880556
# 3  41.895505 -87.691541    NBA  Chicago Bulls  United Center      41.880556
# 4  41.893190 -87.667530    NBA  Chicago Bulls  United Center      41.880556
#
#    team_longitude     state     city
# 0      -87.674167  Illinois  Chicago
# 1      -87.674167  Illinois  Chicago
# 2      -87.674167  Illinois  Chicago
# 3      -87.674167  Illinois  Chicago
# 4      -87.674167  Illinois  Chicago
